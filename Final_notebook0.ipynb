# %%
import pandas as pd

# %%
#Read the whole workbook
s1 = pd.ExcelFile(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx")

#Read the sheet1
sheet1 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=0)
#Read the sheet2
sheet2 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=1)
#Read the sheet3
sheet3 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=2)

# %%
#Display the sheet names in the workbook
read_sheet_names = s1.sheet_names
print(read_sheet_names,"\n")
# Out:
# ['2017 update', 'Jan 2015 update', 'July 2013 update (old)']

# %%
#Display the records in the first sheet
sheet1
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
#For sheet2 change the header with the first row

newhead = sheet2.iloc[0] 
sheet2 = sheet2[1:] 
sheet2.columns = newhead

# %%
#For sheet3 change the header with the first row

newhead = sheet3.iloc[0] 
sheet3 = sheet3[1:] 
sheet3.columns = newhead

# %%
#Drop unnecessary columns from the sheet1
drop1 = ['story','alternative name','NO OF RECORDS STOLEN','interesting story','UNUSED' , 'UNUSED.1', 'Exclude', 'Unnamed: 13', '1st source link', '2nd source link', '3rd source', 'source name']
sheet1 = sheet1[[col for col in sheet1.columns if col not in drop1]]

3#Drop a particular row
sheet1.drop(sheet1.index[0])
# Out:
#                                              ENTITY YEAR RECORDS LOST  \
# 1                                               AOL    0     92000000
# 2                         Automatic Data Processing    1       125000
# 3                                   Ameritrade Inc.    1       200000
# 4                                         Citigroup    1      3900000
# 5                       Cardsystems Solutions Inc.     1     40000000
# 6                                   Hewlett Packard    2       200000
# 7                        Countrywide Financial Corp    2      2600000
# 8                                              KDDI    2      4000000
# 9                        T-Mobile, Deutsche Telecom    2     17000000
# 10                                              AOL    2     20000000
# 11                           US Dept of Vet Affairs    2     26500000
# 12                                    Texas Lottery    3        89000
# ...

# %%
#Rename columns of sheet1 having inconsistencies in name
sheet1=sheet1.rename(columns = {'Entity':'ENTITY','records lost':'RECORDS LOST' })

# %%
#Change values for DATA SENSITIVITY Column sheet_1

#Error: There were some values of type string in Data Sensitivity column which did not get changed with these commands,
#corrected this error in the final notebook.
#Also, did not convert the YEAR column in the form of year (Example: years are encoded (0=2004, 8 = 2012, 9 = 2013,
#10=2014, 11=2015, 12=2016, 13 = 2017, 14=latest), which is done in the final notebook.

sheet1.loc[sheet1['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 20, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 300, 'DATA SENSITIVITY'] = 'Credit card information'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 4000, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 50000, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
#Drop unnecessary columns from the sheet2
drop2 = ['story','alternative name','NO OF RECORDS STOLEN','interesting story','UNUSED' , 'Link to individual study' , 'Exclude' , '1st source link', '2nd source link', '3rd source', 'source name']
sheet2 = sheet2[[col for col in sheet2.columns if col not in drop2]]

#Drop empty columns if all values of the column are NaN
sheet2 = sheet2.dropna(axis=1,how='all')

#Drop a particular row
sheet2.drop(sheet2.index[0])
# Out:
# 0                                            Entity YEAR  \
# 2                                               AOL    0
# 3                                   Ameritrade Inc.    1
# 4                         Automatic Data Processing    1
# 5                       Cardsystems Solutions Inc.     1
# 6                                         Citigroup    1
# 7                                               AOL    2
# 8                        Countrywide Financial Corp    2
# 9                                   Hewlett Packard    2
# 10                                             KDDI    2
# 11                       T-Mobile, Deutsche Telecom    2
# 12                           US Dept of Vet Affairs    2
# 13     City and Hackney Teaching Primary Care Trust    3
# 14                                     Compass Bank    3
# 15                              Dai Nippon Printing    3
# 16                         Driving Standards Agency    3
# ...

# %%
#Rename columns of sheet2 having inconsistencies

sheet2=sheet2.rename(columns = {'Entity':'ENTITY','records lost':'RECORDS LOST'})

# %%
#Change values for column YEAR sheet2

sheet2.loc[sheet2['YEAR'] == 0, 'YEAR'] = 2004
sheet2.loc[sheet2['YEAR'] == 1, 'YEAR'] = 2005
sheet2.loc[sheet2['YEAR'] == 2, 'YEAR'] = 2006
sheet2.loc[sheet2['YEAR'] == 3, 'YEAR'] = 2007
sheet2.loc[sheet2['YEAR'] == 4, 'YEAR'] = 2008
sheet2.loc[sheet2['YEAR'] == 5, 'YEAR'] = 2009
sheet2.loc[sheet2['YEAR'] == 6, 'YEAR'] = 2010
sheet2.loc[sheet2['YEAR'] == 7, 'YEAR'] = 2011
sheet2.loc[sheet2['YEAR'] == 8, 'YEAR'] = 2012
sheet2.loc[sheet2['YEAR'] == 9, 'YEAR'] = 2013
sheet2.loc[sheet2['YEAR'] == 10, 'YEAR'] = 2014
sheet2.loc[sheet2['YEAR'] == 11, 'YEAR'] = 'latest'
sheet2.loc[sheet2['YEAR'] == 12, 'YEAR'] = 'latest'

# %%
#Change values for DATA SENSITIVITY Column sheet2

sheet2.loc[sheet2['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 20, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 300, 'DATA SENSITIVITY'] = 'Credit card information'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 4000, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 50000, 'DATA SENSITIVITY'] = 'Full bank account details'

sheet2.loc[sheet2['DATA SENSITIVITY'] == 2, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 3, 'DATA SENSITIVITY'] = 'Credit card information'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 4, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet2.loc[sheet2['DATA SENSITIVITY'] == 5, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
#Drop a particular row
sheet2.drop(sheet2.index[0])
# Out:
# 0                                            ENTITY    YEAR  \
# 2                                               AOL    2004
# 3                                   Ameritrade Inc.    2005
# 4                         Automatic Data Processing    2005
# 5                       Cardsystems Solutions Inc.     2005
# 6                                         Citigroup    2005
# 7                                               AOL    2006
# 8                        Countrywide Financial Corp    2006
# 9                                   Hewlett Packard    2006
# 10                                             KDDI    2006
# 11                       T-Mobile, Deutsche Telecom    2006
# 12                           US Dept of Vet Affairs    2006
# 13     City and Hackney Teaching Primary Care Trust    2007
# 14                                     Compass Bank    2007
# 15                              Dai Nippon Printing    2007
# 16                         Driving Standards Agency    2007
# ...

# %%
#Drop unnecessary columns from the sheet3
drop3 = ['story','alternative name','NO OF RECORDS STOLEN','interesting story','UNUSED' , 'Link to individual study' , 'Exclude' , '1st source link', '2nd source link', '3rd source', 'source name']
sheet3 = sheet3[[col for col in sheet3.columns if col not in drop3]]

#Drop empty columns if all values of the column are NaN
sheet3 = sheet3.dropna(axis=1,how='all')

#Drop a particular row
sheet3.drop(sheet3.index[0])
# Out:
# 0                                             Entity YEAR records lost  \
# 2                             Accendo Insurance Co.     7       175350
# 3                         Affinity Health Plan, Inc.    5       344579
# 4             Ankle & foot Center of Tampa Bay, Inc.    6       156000
# 5                                                AOL    0     92000000
# 6                                                AOL    2     20000000
# 7                                              Apple    8  12,367,232
# 8                                              Apple    9       275000
# 9                                               AT&T    4       113000
# 10                                              AT&T    6       114000
# 11                                     Auction.co.kr    4   18,000,000
# 12                         Automatic Data Processing    1       125000
# 13                                       AvMed, Inc.    5      1220000
# ...

# %%
#Rename columns of sheet_3 having inconsistencies
sheet3=sheet3.rename(columns = {'Entity':'ENTITY','records lost':'RECORDS LOST'})

# %%
#Change values for column YEAR sheet3

sheet3.loc[sheet3['YEAR'] == 0, 'YEAR'] = 2004
sheet3.loc[sheet3['YEAR'] == 1, 'YEAR'] = 2005
sheet3.loc[sheet3['YEAR'] == 2, 'YEAR'] = 2006
sheet3.loc[sheet3['YEAR'] == 3, 'YEAR'] = 2007
sheet3.loc[sheet3['YEAR'] == 4, 'YEAR'] = 2008
sheet3.loc[sheet3['YEAR'] == 5, 'YEAR'] = 2009
sheet3.loc[sheet3['YEAR'] == 6, 'YEAR'] = 2010
sheet3.loc[sheet3['YEAR'] == 7, 'YEAR'] = 2011
sheet3.loc[sheet3['YEAR'] == 8, 'YEAR'] = 2012
sheet3.loc[sheet3['YEAR'] == 9, 'YEAR'] = 2013

# %%
#Change values for DATA SENSITIVITY Column sheet3

sheet3.loc[sheet3['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet3.loc[sheet3['DATA SENSITIVITY'] == 2, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet3.loc[sheet3['DATA SENSITIVITY'] == 3, 'DATA SENSITIVITY'] = 'Credit card information'
sheet3.loc[sheet3['DATA SENSITIVITY'] == 4, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet3.loc[sheet3['DATA SENSITIVITY'] == 5, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
sheet1.to_csv('Cleaned_sheet2.csv', sep='\t')

# %%
#Errors:

#1. There were some values of type string in Data Sensitivity column which didnot change in this notebook, so
#corrected this error in the final notebook.
#2. Also, did not convert the YEAR column in the form of year (Example: years are encoded (0=2004, 8 = 2012, 9 = 2013,
#10=2014, 11=2015, 12=2016, 13 = 2017, 14=latest), which is done in the final notebook.
#3. Didnot approximate UNKNOWN FIGURES (Example: (use 3m, 4m, 5m or 10m to approximate unknown figures))
