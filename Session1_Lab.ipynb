# %%
import pandas as pd

# %%
#Read the whole workbook
session1 = pd.ExcelFile(r"C:\Users\Tanushree\Downloads\Session1.xlsx")

#Read the sheet1
sheet_1 = pd.read_excel(r"C:\Users\Tanushree\Downloads\Session1.xlsx",sheetname=0)
#Read the sheet2
sheet_2 = pd.read_excel(r"C:\Users\Tanushree\Downloads\Session1.xlsx",sheetname=1)
#Read the sheet3
sheet_3 = pd.read_excel(r"C:\Users\Tanushree\Downloads\Session1.xlsx",sheetname=2)

# %%
#Display the sheet names in the workbook
read_sheet_names = session1.sheet_names
print(read_sheet_names,"\n")
# Out:
# ['2017 update', 'Jan 2015 update', 'July 2013 update (old)']

# %%
#Display the records in the first sheet
sheet_1

#Similarly for sheet_2 & sheet_3
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
#For sheet_2 change the header with the first row

new_head = sheet_2.iloc[0] 
sheet_2 = sheet_2[1:] 
sheet_2.columns = new_head

# %%
#For sheet_3 change the header with the first row

new_head = sheet_3.iloc[0] 
sheet_3 = sheet_3[1:] 
sheet_3.columns = new_head

# %%
#Drop unnecessary columns from the sheet_1
drop1 = ['interesting story','UNUSED' , 'UNUSED.1', 'Exclude', 'Unnamed: 13', '1st source link', '2nd source link', '3rd source', 'source name']
sheet_1 = sheet_1[[col for col in sheet_1.columns if col not in drop1]]

#Drop a particular row
sheet_1.drop(sheet_1.index[0])
# Out:
#                                              Entity  \
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# 17                         Driving Standards Agency
# ...

# %%
#Drop unnecessary columns from the sheet_2
drop2 = ['INTERESTING STORY','UNUSED' , 'Link to individual study' , 'Exclude' , '1st source link', '2nd source link', '3rd source', 'source name']
sheet_2 = sheet_2[[col for col in sheet_2.columns if col not in drop2]]

#Drop a particular row
sheet_2.drop(sheet_2.index[0])
# Out:
# 0                                            Entity  \
# 2                                               AOL
# 3                                   Ameritrade Inc.
# 4                         Automatic Data Processing
# 5                       Cardsystems Solutions Inc.
# 6                                         Citigroup
# 7                                               AOL
# 8                        Countrywide Financial Corp
# 9                                   Hewlett Packard
# 10                                             KDDI
# 11                       T-Mobile, Deutsche Telecom
# 12                           US Dept of Vet Affairs
# 13     City and Hackney Teaching Primary Care Trust
# 14                                     Compass Bank
# 15                              Dai Nippon Printing
# 16                         Driving Standards Agency
# 17                        Driving Standards Agency,
# 18           Fidelity National Information Services
# ...

# %%
#Drop unnecessary columns from the sheet_3
drop3 = ['INTERESTING STORY','UNUSED' , 'Link to individual study' , 'Exclude' , '1st source link', '2nd source link', '3rd source', 'source name']
sheet_3 = sheet_3[[col for col in sheet_3.columns if col not in drop3]]

#Drop empty columns if all values of the column are NaN
sheet_3 = sheet_3.dropna(axis=1,how='all')

#Drop a particular row
sheet_3.drop(sheet_3.index[0])
# Out:
# 0                                             Entity  \
# 2                             Accendo Insurance Co.
# 3                         Affinity Health Plan, Inc.
# 4             Ankle & foot Center of Tampa Bay, Inc.
# 5                                                AOL
# 6                                                AOL
# 7                                              Apple
# 8                                              Apple
# 9                                               AT&T
# 10                                              AT&T
# 11                                     Auction.co.kr
# 12                         Automatic Data Processing
# 13                                       AvMed, Inc.
# 14                                           Betfair
# 15                             Bethesda Game Studios
# 16                                          Blizzard
# 17               Blue Cross Blue Shield of Tennessee
# 18                    BNY Mellon Shareowner Services
# ...

# %%
#Rename columns of sheet_1 having inconsistencies
sheet_1=sheet_1.rename(columns = {'Entity':'ENTITY','alternative name':'ALTERNATIVE NAME', 'story':'STORY',
                                        'records lost':'RECORDS LOST','interesting story':'INTERESTING STORY' })

#Rename columns of sheet_2 having inconsistencies
sheet_2=sheet_2.rename(columns = {'Entity':'ENTITY','alternative name':'ALTERNATIVE NAME', 'story':'STORY',
                                        'records lost':'RECORDS LOST','interesting story':'INTERESTING STORY' })

#Rename columns of sheet_3 having inconsistencies
sheet_3=sheet_3.rename(columns = {'Entity':'ENTITY','alternative name':'ALTERNATIVE NAME', 'story':'STORY',
                                        'records lost':'RECORDS LOST','interesting story':'INTERESTING STORY' })

# %%
#Change values for column YEAR sheet_3

sheet_3.loc[sheet_3['YEAR'] == 0, 'YEAR'] = 2004
sheet_3.loc[sheet_3['YEAR'] == 1, 'YEAR'] = 2005
sheet_3.loc[sheet_3['YEAR'] == 2, 'YEAR'] = 2006
sheet_3.loc[sheet_3['YEAR'] == 3, 'YEAR'] = 2007
sheet_3.loc[sheet_3['YEAR'] == 4, 'YEAR'] = 2008
sheet_3.loc[sheet_3['YEAR'] == 5, 'YEAR'] = 2009
sheet_3.loc[sheet_3['YEAR'] == 6, 'YEAR'] = 2010
sheet_3.loc[sheet_3['YEAR'] == 7, 'YEAR'] = 2011
sheet_3.loc[sheet_3['YEAR'] == 8, 'YEAR'] = 2012
sheet_3.loc[sheet_3['YEAR'] == 9, 'YEAR'] = 2013

# %%
#Change values for column YEAR sheet_2

sheet_2.loc[sheet_2['YEAR'] == 0, 'YEAR'] = 2004
sheet_2.loc[sheet_2['YEAR'] == 1, 'YEAR'] = 2005
sheet_2.loc[sheet_2['YEAR'] == 2, 'YEAR'] = 2006
sheet_2.loc[sheet_2['YEAR'] == 3, 'YEAR'] = 2007
sheet_2.loc[sheet_2['YEAR'] == 4, 'YEAR'] = 2008
sheet_2.loc[sheet_2['YEAR'] == 5, 'YEAR'] = 2009
sheet_2.loc[sheet_2['YEAR'] == 6, 'YEAR'] = 2010
sheet_2.loc[sheet_2['YEAR'] == 7, 'YEAR'] = 2011
sheet_2.loc[sheet_2['YEAR'] == 8, 'YEAR'] = 2012
sheet_2.loc[sheet_2['YEAR'] == 9, 'YEAR'] = 2013
sheet_2.loc[sheet_2['YEAR'] == 10, 'YEAR'] = 2014
sheet_2.loc[sheet_2['YEAR'] == 11, 'YEAR'] = 'latest'
sheet_2.loc[sheet_2['YEAR'] == 12, 'YEAR'] = 'latest'

# %%
#Change values for column YEAR sheet_1

sheet_1.loc[sheet_1['YEAR'] == 0, 'YEAR'] = 2004
sheet_1.loc[sheet_1['YEAR'] == 1, 'YEAR'] = 2005
sheet_1.loc[sheet_1['YEAR'] == 2, 'YEAR'] = 2006
sheet_1.loc[sheet_1['YEAR'] == 3, 'YEAR'] = 2007
sheet_1.loc[sheet_1['YEAR'] == 4, 'YEAR'] = 2008
sheet_1.loc[sheet_1['YEAR'] == 5, 'YEAR'] = 2009
sheet_1.loc[sheet_1['YEAR'] == 6, 'YEAR'] = 2010
sheet_1.loc[sheet_1['YEAR'] == 7, 'YEAR'] = 2011
sheet_1.loc[sheet_1['YEAR'] == 8, 'YEAR'] = 2012
sheet_1.loc[sheet_1['YEAR'] == 9, 'YEAR'] = 2013
sheet_1.loc[sheet_1['YEAR'] == 10, 'YEAR'] = 2014
sheet_1.loc[sheet_1['YEAR'] == 11, 'YEAR'] = 'latest'
sheet_1.loc[sheet_1['YEAR'] == 12, 'YEAR'] = 'latest'
sheet_1.loc[sheet_1['YEAR'] == 13, 'YEAR'] = 2017
sheet_1.loc[sheet_1['YEAR'] == 14, 'YEAR'] = 'latest'

# %%
#Change values for DATA SENSITIVITY Column sheet_3

sheet_3.loc[sheet_3['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet_3.loc[sheet_3['DATA SENSITIVITY'] == 2, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet_3.loc[sheet_3['DATA SENSITIVITY'] == 3, 'DATA SENSITIVITY'] = 'Credit card information'
sheet_3.loc[sheet_3['DATA SENSITIVITY'] == 4, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet_3.loc[sheet_3['DATA SENSITIVITY'] == 5, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
#Change values for DATA SENSITIVITY Column sheet_2

sheet_2.loc[sheet_2['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet_2.loc[sheet_2['DATA SENSITIVITY'] == 2, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet_2.loc[sheet_2['DATA SENSITIVITY'] == 3, 'DATA SENSITIVITY'] = 'Credit card information'
sheet_2.loc[sheet_2['DATA SENSITIVITY'] == 4, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet_2.loc[sheet_2['DATA SENSITIVITY'] == 5, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
#Change values for DATA SENSITIVITY Column sheet_1

sheet_1.loc[sheet_1['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet_1.loc[sheet_1['DATA SENSITIVITY'] == 2, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet_1.loc[sheet_1['DATA SENSITIVITY'] == 3, 'DATA SENSITIVITY'] = 'Credit card information'
sheet_1.loc[sheet_1['DATA SENSITIVITY'] == 4, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet_1.loc[sheet_1['DATA SENSITIVITY'] == 5, 'DATA SENSITIVITY'] = 'Full bank account details'

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
import pandas as pd
writer = pd.ExcelWriter('Cleaned_Sheet.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
sheet_1.to_excel(writer, sheet_name='2017 Update')
sheet_2.to_excel(writer, sheet_name='Jan 2015 update')
sheet_3.to_excel(writer, sheet_name='July 2013 update (old)')
# Close the Pandas Excel writer and output the Excel file.
writer.save()

sheet_1.to_excel('Clean_Sheet1.xlsx',sheet_name='2017 Update', index=False)
sheet_2.to_excel('Clean_Sheet2.xlsx',sheet_name='Jan 2015 update', index=False)
sheet_3.to_excel('Clean_Sheet3.xlsx',sheet_name='July 2013 update (old)', index=False)
