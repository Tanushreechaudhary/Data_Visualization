# %%
import pandas as pd

# %%
#Read the whole workbook
s1 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx")

#Read the sheet1
sheet1 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=0)
#Read the sheet2
sheet2 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=1)
#Read the sheet3
sheet3 = pd.read_excel(r"C:\Users\Tanushree\Desktop\UNIVERSITY\Quarter 4\Dashboard\Lab1_Session\Session1.xlsx",sheetname=2)

# %%
#Display the sheet names in the workbook
print(read_sheet_names,"\n")
# Out:
# ['2017 update', 'Jan 2015 update', 'July 2013 update (old)']

# %%
#Drop unnecessary columns from the sheet1
drop1 = ['story','alternative name','NO OF RECORDS STOLEN','interesting story','UNUSED' , 'UNUSED.1', 'Exclude', 'Unnamed: 13', '1st source link', '2nd source link', '3rd source', 'source name']
sheet1 = sheet1[[col for col in sheet1.columns if col not in drop1]]

# %%
#Rename columns of sheet1 having inconsistencies in name
sheet1=sheet1.rename(columns = {'Entity':'ENTITY','records lost':'RECORDS LOST' })

# %%
sheet1.loc[sheet1['DATA SENSITIVITY'] == 1, 'DATA SENSITIVITY'] = 'Just email address/Online information'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 20, 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 300, 'DATA SENSITIVITY'] = 'Credit card information'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 4000, 'DATA SENSITIVITY'] = 'Email password/Health records'
sheet1.loc[sheet1['DATA SENSITIVITY'] == 50000, 'DATA SENSITIVITY'] = 'Full bank account details'

#Error1 corrected
#Encountered some string values in column with numeric values
sheet1.loc[sheet1['DATA SENSITIVITY'] == '20', 'DATA SENSITIVITY'] = 'SSN/Personal details'
sheet1.loc[sheet1['DATA SENSITIVITY'] == '300', 'DATA SENSITIVITY'] = 'Credit card information'

# %%
#Change values for column YEAR sheet1

sheet1.loc[sheet1['YEAR'] == 0, 'YEAR'] = 2004
sheet1.loc[sheet1['YEAR'] == 1, 'YEAR'] = 2005
sheet1.loc[sheet1['YEAR'] == 2, 'YEAR'] = 2006
sheet1.loc[sheet1['YEAR'] == 3, 'YEAR'] = 2007
sheet1.loc[sheet1['YEAR'] == 4, 'YEAR'] = 2008
sheet1.loc[sheet1['YEAR'] == 5, 'YEAR'] = 2009
sheet1.loc[sheet1['YEAR'] == 6, 'YEAR'] = 2010
sheet1.loc[sheet1['YEAR'] == 7, 'YEAR'] = 2011
sheet1.loc[sheet1['YEAR'] == 8, 'YEAR'] = 2012
sheet1.loc[sheet1['YEAR'] == 9, 'YEAR'] = 2013
sheet1.loc[sheet1['YEAR'] == 10, 'YEAR'] = 2014
sheet1.loc[sheet1['YEAR'] == 11, 'YEAR'] = 2015
sheet1.loc[sheet1['YEAR'] == 12, 'YEAR'] = 2016
sheet1.loc[sheet1['YEAR'] == 13, 'YEAR'] = 2017
sheet1.loc[sheet1['YEAR'] == 14, 'YEAR'] = 'latest'

# %%
#Error 2 corrected
#Approximating the UNKNOWN FIGURES

sheet1.loc[sheet1['ENTITY'] == 'OVH', 'RECORDS LOST'] = 5000000
sheet1.loc[sheet1['ENTITY'] == 'UbiSoft', 'RECORDS LOST'] = 10000000

# %%
sheet1
# Out:
#                                              ENTITY  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
#Drop the first row
sheet1.drop(sheet1.index[0])
# Out:
#                                              ENTITY    YEAR RECORDS LOST  \
# 1                                               AOL    2004     92000000
# 2                         Automatic Data Processing    2005       125000
# 3                                   Ameritrade Inc.    2005       200000
# 4                                         Citigroup    2005      3900000
# 5                       Cardsystems Solutions Inc.     2005     40000000
# 6                                   Hewlett Packard    2006       200000
# 7                        Countrywide Financial Corp    2006      2600000
# 8                                              KDDI    2006      4000000
# 9                        T-Mobile, Deutsche Telecom    2006     17000000
# 10                                              AOL    2006     20000000
# 11                           US Dept of Vet Affairs    2006     26500000
# 12                                    Texas Lottery    2007        89000
# ...

# %%
sheet1.to_csv('Cleaned_sheet1.csv', sep='\t')
